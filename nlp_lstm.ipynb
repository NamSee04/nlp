# %% [markdown]
# <a href="https://www.kaggle.com/code/huukhoale/notebookc9e46e7f53?scriptVersionId=247141686" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/NamSee04/nlp
# Out:
# Cloning into 'nlp'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 114 (delta 55), reused 83 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 100.88 KiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# %cd /kaggle/working/nlp/lstm
# Out:
# /kaggle/working/nlp/lstm

# %%
# !pwd
# Out:
# /kaggle/working/nlp/lstm

# %%
# !chmod +x run_colab.sh

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -U datasets

# %%
# !./run_colab.sh
# Out:
# CUDA is available, using GPU.
# Preprocessing English to Vietnamese dataset...
# Preprocessing data...
# README.md: 100%|███████████████████████████████| 665/665 [00:00<00:00, 3.65MB/s]
# (…)-00000-of-00001-8fc21cb8e80d3a2d.parquet: 100%|█| 11.3M/11.3M [00:00<00:00, 1
# (…)-00000-of-00001-858c0e989d9c5637.parquet: 100%|█| 1.42M/1.42M [00:00<00:00, 2
# (…)-00000-of-00001-99e7e50144d1c164.parquet: 100%|█| 1.42M/1.42M [00:00<00:00, 1
# Generating train split: 100%|█| 203272/203272 [00:00<00:00, 1276316.55 examples/
# ...
# Generating valid split: 100%|█| 25409/25409 [00:00<00:00, 1924709.15 examples/s]
# Preprocessing text data...
# ...
# Processing target texts: 100%|███████| 162617/162617 [00:11<00:00, 14484.67it/s]
# Building vocabularies...
# Source vocabulary size: 11554
# Target vocabulary size: 4286
# Preprocessing Vietnamese to English dataset...
# Preprocessing data...
# (…)-00000-of-00001-8fc21cb8e80d3a2d.parquet: 100%|█| 11.3M/11.3M [00:00<00:00, 1
# ...
